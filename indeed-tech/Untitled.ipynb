# %%
import pandas as pd

# %%
url = "https://citrusvanilla.github.io/indeed_techskills2019/processeed_tech_jobs_by_skill_by_month.json"
import requests

response = requests.get(url)

jobs = response.json()
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~/opt/miniconda3/envs/data_engineering/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/opt/miniconda3/envs/data_engineering/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      72
# ---> 73     for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      74         af, socktype, proto, canonname, sa = res
#
# ~/opt/miniconda3/envs/data_engineering/lib/python3.8/socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     917     addrlist = []
# --> 918     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
# ...

# %%
# jobs['python']

# %%
url = "https://citrusvanilla.github.io/indeed_techskills2021/processeed_tech_jobs_by_skill_by_month.json"

# %%
import json

# %%
with open('skills.json', 'w') as outfile:
    json.dump(jobs, outfile)

# %%
jobs
# Out:
# {'.net': {'counts': [9.948572524081786,
#    9.979781732615015,
#    10.178965394006473,
#    10.171715660140837,
#    10.31298967218442,
#    10.342592480975316,
#    10.065923069495494,
#    10.081115632538026,
#    10.090417917152504,
#    10.252714430752006,
#    10.323600043112261,
#    10.158866188707911,
#    10.284026196064746,
#    10.443844925287289,
#    10.463169312176438,
#    10.358029698602406,
#    10.109774608877768,
#    9.898821776076783,
#    9.724038267881113,
#    9.749944907089642,
#    9.748241688326125,
#    9.53104994431965,
#    9.390839817047196,
#    9.289396549422037,
#    9.126855853465194,
#    9.057239053606988,
#    9.1370449790319,
#    8.936901017522693,
#    8.791379637238702,
#    8.710949111805185,
#    8.701272122798988,
#    8.62641175149689,
#    8.67523830380881,
#    8.567449595737777,
#    8.490709662673119,
#    8.49359166958603,
#    8.629651004085778,
#    8.642604297833195,
#    8.697356113210146,
#    8.58404988267091,
# ...
